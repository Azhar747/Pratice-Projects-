# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("E:\\Datatrained projects\\abalone.csv")

# %%
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# #

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# ## Conclusion: There are no null values

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
## Checking the datatypes 
data.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
data['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
ax=sns.countplot(x='Sex',data=data)

# %% [markdown]
# ## Since Sex is the Categorial Column We cannot apply Regression So we are converting it

# %%
sex_dictionary = {'M': 1, 'F' : 2,'I':3}
data['Sex'] = data['Sex'].apply(lambda x: sex_dictionary[x])

# %%
data.dtypes
# Out:
# Sex                 int64
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
## Checking the correration

# %%
corr=data.corr()

# %%
plt.figure(figsize=(15,7),dpi=200)
sns.heatmap(data=corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
data.corr()['Rings'].sort_values()
# Out:
# Sex              -0.351822
# Shucked weight    0.420884
# Viscera weight    0.503819
# Whole weight      0.540390
# Length            0.556720
# Height            0.557467
# Diameter          0.574660
# Shell weight      0.627574
# Rings             1.000000
# Name: Rings, dtype: float64

# %%
sns.scatterplot(x="Rings",y="Shucked weight",data=data)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Shucked weight'>

# %%
sns.scatterplot(x="Rings",y="Shell weight",data=data)
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Shell weight'>

# %%
data["Rings"].value_counts().sort_index()
# Out:
# 1       1
# 2       1
# 3      15
# 4      57
# 5     115
# 6     259
# 7     391
# 8     568
# 9     689
# 10    634
# 11    487
# 12    267
# 13    203
# 14    126
# 15    103
# 16     67
# 17     58
# 18     42
# 19     32
# 20     26
# 21     14
# 22      6
# 23      9
# 24      2
# 25      1
# 26      1
# 27      2
# 29      1
# Name: Rings, dtype: int64

# %% [markdown]
# ## Adding Age column to diffrenciate Young , Middle and Old

# %%
def givingage(row):
    if row['Rings']>=1 and row['Rings']<=8:
        return 1
    elif row['Rings'] >=9 and row['Rings']<=10:
        return 2
    elif row['Rings']>=11 and row['Rings']<=29:
         return 3
    return 0

# %%
data['Age']=data.apply (lambda row: givingage(row),axis=1)

# %%
data.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    1   0.455     0.365   0.095        0.5140          0.2245
# 1    1   0.350     0.265   0.090        0.2255          0.0995
# 2    2   0.530     0.420   0.135        0.6770          0.2565
# 3    1   0.440     0.365   0.125        0.5160          0.2155
# 4    3   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings  Age
# 0          0.1010         0.150     15    3
# 1          0.0485         0.070      7    1
# 2          0.1415         0.210      9    2
# 3          0.1140         0.155     10    2
# 4          0.0395         0.055      7    1

# %%
data.skew().sort_values()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Age              -0.017807
# Sex               0.083056
# Whole weight      0.530959
# Viscera weight    0.591852
# Shell weight      0.620927
# Shucked weight    0.719098
# Rings             1.114102
# Height            3.128817
# dtype: float64

# %% [markdown]
# ## Height is the most skewed So we are removing the skewness.

# %%
sns.displot(data["Height"],kde=True)

# %%
data["Height"]=np.sqrt(data["Height"]) ## Removing the skewness

# %%
sns.displot(data["Height"],kde=True)

# %%
data.skew().sort_values()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height           -0.295641
# Age              -0.017807
# Sex               0.083056
# Whole weight      0.530959
# Viscera weight    0.591852
# Shell weight      0.620927
# Shucked weight    0.719098
# Rings             1.114102
# dtype: float64

# %%
sns.displot(data["Shucked weight"],kde=True)

# %%
data["Shucked weight"]=np.sqrt(data["Shucked weight"])

# %%
sns.displot(data["Shucked weight"],kde=True)

# %%
sns.displot(data["Shell weight"],kde=True)

# %%
data["Shell weight"]=np.sqrt(data["Shell weight"])

# %%
sns.displot(data["Shell weight"],kde=True)

# %%
data["Shell weight"]=np.sqrt(data["Shell weight"])

# %%
sns.displot(data["Shell weight"],kde=True)

# %%
sns.displot(data["Length"],kde=True)

# %%
sns.displot(data["Viscera weight"],kde=True)

# %%
data["Viscera weight"]=np.sqrt(data["Viscera weight"])

# %%
sns.displot(data["Viscera weight"],kde=True)

# %%
sns.displot(data["Whole weight"],kde=True)

# %%
data["Whole weight"]=np.sqrt(data["Whole weight"])

# %%
sns.displot(data["Whole weight"],kde=True)

# %%
sns.displot(data["Diameter"],kde=True)

# %%
data.skew()
# Out:
# Sex               0.083056
# Length           -0.639873
# Diameter         -0.609198
# Height           -0.295641
# Whole weight     -0.236646
# Shucked weight   -0.141443
# Viscera weight   -0.183321
# Shell weight     -0.734821
# Rings             1.114102
# Age              -0.017807
# dtype: float64

# %% [markdown]
# ## Checking the Outliers

# %%
collist=data.columns.values

# %%
ncol=30
nrow=14
plt.figure(figsize=(5*nrow,3*ncol),dpi=200)
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data[collist[i]],color='orange',orient="h")

# %%
ax = sns.boxplot(x="Sex", y="Rings", data=data)
plt.show()

# %%
plt.figure(1)
f, axarr = plt.subplots(3, 2, figsize=(10, 9))
ring = data.Rings.values
axarr[0, 0].scatter(data.Age.values, ring)
axarr[0, 0].set_title('Age')
axarr[0, 1].scatter(data.Sex.values, ring)
axarr[0, 1].set_title('Sex')
axarr[1, 0].scatter(data.Height.values, ring)
axarr[1, 0].set_title('Height')
axarr[2, 0].scatter(data.Length.values, ring)
axarr[2, 0].set_title('Length')
axarr[2, 0].scatter(data.Diameter.values, ring)
axarr[2, 0].set_title('Diameter')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Height of abalones is in the range of 0 to 0.4mm, most abalones are old aged

# %%
sns.factorplot('Age', 'Height', hue = 'Sex', estimator = np.mean, data =data, 
             height = 4.5, aspect = 1.4)
plt.show()

# %% [markdown]
# ## Female has highest height

# %% [markdown]
# ## Traing Test Split

# %%
X=data.drop(['Rings',"Age"],axis=1)

# %%
y=data[['Age']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#       Sex  Length  Diameter    Height  Whole weight  Shucked weight  \
# 1593    3   0.525     0.380  0.367423      0.784219        0.510882
# 111     1   0.465     0.360  0.324037      0.656506        0.414729
# 3271    1   0.520     0.425  0.393700      0.879488        0.544977
# 1089    3   0.450     0.330  0.324037      0.609508        0.431856
# 2918    3   0.600     0.445  0.367423      0.959427        0.667083
# ...   ...     ...       ...       ...           ...             ...
# 3444    2   0.490     0.400  0.339116      0.754321        0.505964
# 466     2   0.670     0.550  0.435890      1.179195        0.736546
# 3092    1   0.510     0.395  0.353553      0.761906        0.493964
# 3772    1   0.575     0.465  0.346410      1.026401        0.718331
# 860     2   0.595     0.475  0.400000      1.067942        0.739594
#
#       Viscera weight  Shell weight
# 1593        0.398748      0.646784
# 111         0.327109      0.646784
# 3271        0.350714      0.710616
# ...

# %%
y_train
# Out:
#       Age
# 1593    1
# 111     2
# 3271    3
# 1089    1
# 2918    2
# ...   ...
# 3444    2
# 466     3
# 3092    3
# 3772    2
# 860     1
#
# [2798 rows x 1 columns]

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logReg=LogisticRegression()

# %%
logReg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=logReg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
import math
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report
acc_score=accuracy_score(y_pred,y_test)
print(acc_score*100)
# Out:
# 63.524292965917326

# %%
mae=mean_absolute_error(y_pred,y_test);
mae
# Out:
# 0.41116751269035534

# %%
rmse = math.sqrt(mean_squared_error(y_pred,y_test))
rmse
# Out:
# 0.7099214022618368

# %%
report=classification_report(y_pred,y_test)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.77      0.73      0.75       506
#            2       0.34      0.50      0.41       301
#            3       0.78      0.62      0.69       572
#
#     accuracy                           0.64      1379
#    macro avg       0.63      0.62      0.62      1379
# weighted avg       0.68      0.64      0.65      1379

# %% [markdown]
# ## Hyperparmater Tuning Logistic Regression

# %%
# example of grid searching key hyperparametres for logistic regression
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
grid_search = GridSearchCV(estimator=logReg, param_grid=grid, n_jobs=-1,scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X_train,y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.656537 using {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
logReg_CV=LogisticRegression(C=1.0,penalty='l2',solver='newton-cg')

# %%
logReg_CV.fit(X_train,y_train)
# Out:
# LogisticRegression(solver='newton-cg')

# %%
y_pred_CV=logReg.predict(X_test)

# %%
acc_score=accuracy_score(y_pred_CV,y_test)
print(acc_score*100)
# Out:
# 63.524292965917326

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ran_model=RandomForestClassifier()

# %%
ran_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_ran=ran_model.predict(X_test)

# %%
acc_score=accuracy_score(y_pred_ran,y_test)
print(acc_score*100)
# Out:
# 64.61203770848441

# %%
mae=mean_absolute_error(y_pred_ran,y_test);

# %%
mae
# Out:
# 0.39086294416243655

# %%
rmse = math.sqrt(mean_squared_error(y_pred_ran,y_test))
rmse
# Out:
# 0.6817841202734175

# %%
rmse = math.sqrt(mean_squared_error(y_pred_ran,y_test))
rmse
# Out:
# 0.6817841202734175

# %% [markdown]
# ## Hyper Parameter Tuning Random Forest

# %%
n_estimators = [100,200]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100]
max_features=["auto","sqrt"]
bootstrap=[True,False]
min_samples_leaf = [1, 2, 5, 10]

# %%
param_grid ={"n_estimators":n_estimators,
              "max_depth": max_depth,  
              "min_samples_split":min_samples_split, 
             "min_samples_leaf":min_samples_leaf, 
             "bootstrap":bootstrap, 
            "max_features":max_features}

print(param_grid)
# Out:
# {'n_estimators': [100, 200], 'max_depth': [5, 8, 15, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10], 'bootstrap': [True, False], 'max_features': ['auto', 'sqrt']}

# %%
rf_grid=GridSearchCV(estimator=ran_model,param_grid=param_grid,cv=3,n_jobs=4,verbose=2)

# %%
#rf_grid.fit(X_train,y_train)

# %% [markdown]
# Fitting 3 folds for each of 800 candidates, totalling 2400 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=4,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [5, 8, 15, 25, 30],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 5, 10],
#                          'min_samples_split': [2, 5, 10, 15, 100],
#                          'n_estimators': [100, 200]},
#              verbose=2)

# %%
#rf_grid.best_params_

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=200,max_depth=8, min_samples_split=5,min_samples_leaf=1,bootstrap=True,max_features='sqrt')

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=8, max_features='sqrt', min_samples_split=5,
#                        n_estimators=200)

# %%
y_pred_ran_CV=model.predict(X_test)

# %%
acc_score=accuracy_score(y_pred_ran_CV,y_test)
print(acc_score*100)
# Out:
# 65.3372008701958

# %%
mae=mean_absolute_error(y_pred_ran_CV,y_test);

# %%
mae
# Out:
# 0.3799854967367658

# %%
report=classification_report(y_pred_ran_CV,y_test)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      0.78      0.76       465
#            2       0.49      0.51      0.50       424
#            3       0.71      0.66      0.68       490
#
#     accuracy                           0.65      1379
#    macro avg       0.65      0.65      0.65      1379
# weighted avg       0.66      0.65      0.65      1379

# %% [markdown]
# # Decision Tree Classfier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc_model=DecisionTreeClassifier()

# %%
dtc_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dc=dtc_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc_score_dc=accuracy_score(y_pred_dc,y_test)

# %%
acc_score_dc*100
# Out:
# 59.608411892675846

# %%
print(classification_report(y_pred_dc,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.71      0.71      0.71       483
#            2       0.46      0.47      0.47       437
#            3       0.60      0.60      0.60       459
#
#     accuracy                           0.60      1379
#    macro avg       0.59      0.59      0.59      1379
# weighted avg       0.60      0.60      0.60      1379

# %% [markdown]
# ## Hyperparameter tuning Decision Tree Classifer

# %%
params = {
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'criterion': ["gini", "entropy"]
}

# %%
dc_grid=GridSearchCV(estimator=dtc_model,param_grid=params,cv=3,n_jobs=4,verbose=2)

# %%
dc_grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=4,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              verbose=2)

# %%
dc_grid.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 100}

# %%
dtc_model_CV=DecisionTreeClassifier(criterion='entropy',max_depth=5,min_samples_leaf=100)

# %%
dtc_model_CV.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=100)

# %%
y_pred_dc_CV=dtc_model.predict(X_test)

# %%
acc_score_dc_CV=accuracy_score(y_pred_dc_CV,y_test)

# %%
acc_score_dc_CV
# Out:
# 0.5960841189267585

# %%
report=classification_report(y_pred_dc_CV,y_test)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.71      0.71      0.71       483
#            2       0.46      0.47      0.47       437
#            3       0.60      0.60      0.60       459
#
#     accuracy                           0.60      1379
#    macro avg       0.59      0.59      0.59      1379
# weighted avg       0.60      0.60      0.60      1379

# %% [markdown]
# ## So the best Algorithim is Random Forest since its Accuracy Score is 65%
